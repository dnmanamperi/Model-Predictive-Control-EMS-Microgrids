# %% [markdown]
# Used only past 24 h * 3 - Univariative LSTM  KAGGLE

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from lightgbm import LGBMRegressor

# %%
# Load dataset
df = pd.read_csv("kaggle_weather_15min_interpolated_YEAR.csv")

# Convert timestamp
df["timestamp"] = pd.to_datetime(df["timestamp"])

# Sort by time (VERY IMPORTANT)
df = df.sort_values("timestamp").reset_index(drop=True)

df.head()
# Out:
#             timestamp  temperature_C  humidity_percent  cloud_cover_percent  \
# 0 2007-04-01 00:00:00            4.7             99.00                100.0
# 1 2007-04-01 00:15:00            4.4             99.25                100.0
# 2 2007-04-01 00:30:00            4.1             99.50                100.0
# 3 2007-04-01 00:45:00            3.8             99.75                100.0
# 4 2007-04-01 01:00:00            3.5            100.00                100.0
#
#    solar_irradiance_Wm2  wind_speed_ms  load_normalize
# 0                   0.0          6.400           3.480
# 1                   0.0          6.075           4.458
# 2                   0.0          5.750           1.568
# 3                   0.0          5.425           1.374
# 4                   0.0          5.100           1.432

# %%
df.tail()
# Out:
#       timestamp  temperature_C  humidity_percent  cloud_cover_percent  \
# 35131       NaT            NaN               NaN                  NaN
# 35132       NaT            NaN               NaN                  NaN
# 35133       NaT            NaN               NaN                  NaN
# 35134       NaT            NaN               NaN                  NaN
# 35135       NaT            NaN               NaN                  NaN
#
#        solar_irradiance_Wm2  wind_speed_ms  load_normalize
# 35131                   NaN            NaN             NaN
# 35132                   NaN            NaN             NaN
# 35133                   NaN            NaN             NaN
# 35134                   NaN            NaN             NaN
# 35135                   NaN            NaN             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35136 entries, 0 to 35135
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   timestamp             32160 non-null  datetime64[ns]
#  1   temperature_C         32160 non-null  float64
#  2   humidity_percent      32160 non-null  float64
#  3   cloud_cover_percent   32160 non-null  float64
#  4   solar_irradiance_Wm2  32160 non-null  float64
#  5   wind_speed_ms         32160 non-null  float64
#  6   load_normalize        32160 non-null  float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 1.9 MB

# %%
#  Interpolate missing values (linear for time series)
# df = df.interpolate(method="linear")
df =df.dropna()  # Drop any remaining NaN values (if any)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32160 entries, 0 to 32159
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   timestamp             32160 non-null  datetime64[ns]
#  1   temperature_C         32160 non-null  float64
#  2   humidity_percent      32160 non-null  float64
#  3   cloud_cover_percent   32160 non-null  float64
#  4   solar_irradiance_Wm2  32160 non-null  float64
#  5   wind_speed_ms         32160 non-null  float64
#  6   load_normalize        32160 non-null  float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 2.0 MB
# None

# %%
plt.figure(figsize=(20,4))
plt.plot(df["timestamp"], df["load_normalize"])
plt.title("Normalized Load Output (15-min)")
plt.xlabel("Time")
plt.ylabel("Normalized Load")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.heatmap(
    df[[
        "load_normalize",
        "solar_irradiance_Wm2",
        "cloud_cover_percent",
        "temperature_C",
        "humidity_percent",
        "wind_speed_ms"
    ]].corr(),
    annot=True,
    cmap="coolwarm"
)
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# # Time-based features
# df["hour"] = df["timestamp"].dt.hour
# df["minute"] = df["timestamp"].dt.minute
# df["dayofyear"] = df["timestamp"].dt.dayofyear

# # Solar power lags
# df["solar_lag_1"] = df["solar_normalize"].shift(1)
# df["solar_lag_2"] = df["solar_normalize"].shift(2)
# df["solar_lag_4"] = df["solar_normalize"].shift(4)

# #Drop NaN
# df = df.dropna()

# Ramp rate (intra-hour variability)
#df["solar_ramp"] = df["solar_normalize"] - df["solar_lag_1"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32160 entries, 0 to 32159
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   timestamp             32160 non-null  datetime64[ns]
#  1   temperature_C         32160 non-null  float64
#  2   humidity_percent      32160 non-null  float64
#  3   cloud_cover_percent   32160 non-null  float64
#  4   solar_irradiance_Wm2  32160 non-null  float64
#  5   wind_speed_ms         32160 non-null  float64
#  6   load_normalize        32160 non-null  float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 2.0 MB

# %%
data = df[["load_normalize"]].values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
import numpy as np

n_input = 96 * 3   # 3 days
n_output = 96      # 1 day

X = []
y = []

for i in range(0, len(data_scaled) - n_input - n_output, 96):
    X.append(data_scaled[i:i+n_input])
    y.append(data_scaled[i+n_input:i+n_input+n_output,0])

X = np.array(X)
y = np.array(y)

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (331, 288, 1)
# y shape: (331, 96)

# %%
len(X), len(y)
# Out:
# (331, 331)

# %%
train_size = int(0.7 * len(X))
val_size   = int(0.15 * len(X))

X_train = X[:train_size]
X_val   = X[train_size:train_size+val_size]
X_test  = X[train_size+val_size:]

y_train = y[:train_size]
y_val   = y[train_size:train_size+val_size]
y_test  = y[train_size+val_size:]

# %%
import matplotlib.pyplot as plt

day = 20  # change this to see different days

plt.figure(figsize=(14,5))

plt.plot(y_test[day], label="Actual")

plt.title(f"Actual Solar - Day {day}")
plt.xlabel("Time Steps (15-min intervals)")
plt.ylabel("Solar Power")
plt.legend()

plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()

model.add(LSTM(128, return_sequences=True, input_shape=(288, 1)))
model.add(Dropout(0.2))

model.add(LSTM(64))
model.add(Dropout(0.2))

model.add(Dense(96, activation="relu"))

model.compile(
    optimizer='adam',
    loss='huber'
)

model.summary()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 288, 128)       │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 288, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 96)             │         6,240 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,208 (477.38 KB)
#  Trainable params: 122,208 (477.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,# 300
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 454ms/step - loss: 0.0104 - val_loss: 0.0155
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 338ms/step - loss: 0.0079 - val_loss: 0.0145
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 282ms/step - loss: 0.0071 - val_loss: 0.0129
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - loss: 0.0068 - val_loss: 0.0120
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - loss: 0.0066 - val_loss: 0.0124
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 294ms/step - loss: 0.0061 - val_loss: 0.0106
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - loss: 0.0062 - val_loss: 0.0120
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - loss: 0.0060 - val_loss: 0.0107
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - loss: 0.0059 - val_loss: 0.0114
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 335ms/step - loss: 0.0058 - val_loss: 0.0110
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0057 - val_loss: 0.0105
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - loss: 0.0059 - val_loss: 0.0110
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 332ms/step - loss: 0.0058 - val_loss: 0.0102
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - loss: 0.0058 - val_loss: 0.0116
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0057 - val_loss: 0.0100
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step - loss: 0.0056 - val_loss: 0.0108
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 321ms/step - loss: 0.0057 - val_loss: 0.0103
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - loss: 0.0056 - val_loss: 0.0109
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - loss: 0.0057 - val_loss: 0.0101
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - loss: 0.0053 - val_loss: 0.0101
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - loss: 0.0054 - val_loss: 0.0099
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - loss: 0.0051 - val_loss: 0.0091
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.0050 - val_loss: 0.0099
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0052 - val_loss: 0.0094
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 336ms/step - loss: 0.0053 - val_loss: 0.0096
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - loss: 0.0052 - val_loss: 0.0099
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - loss: 0.0054 - val_loss: 0.0100
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - loss: 0.0053 - val_loss: 0.0097
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0054 - val_loss: 0.0094
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 259ms/step - loss: 0.0053 - val_loss: 0.0095
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.0052 - val_loss: 0.0095
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0053 - val_loss: 0.0096
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - loss: 0.0052 - val_loss: 0.0092
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 322ms/step - loss: 0.0052 - val_loss: 0.0096
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 333ms/step - loss: 0.0052 - val_loss: 0.0098
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 322ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0053 - val_loss: 0.0103
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 437ms/step - loss: 0.0051 - val_loss: 0.0094
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 331ms/step - loss: 0.0052 - val_loss: 0.0101
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0052 - val_loss: 0.0091
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0052 - val_loss: 0.0107
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.0054 - val_loss: 0.0101
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.0053 - val_loss: 0.0097
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 406ms/step - loss: 0.0050 - val_loss: 0.0097
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - loss: 0.0053 - val_loss: 0.0098

# %%
y_pred = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 422ms/step

# %%
# reshape for inverse
y_pred_inv = scaler.inverse_transform(y_pred.reshape(-1, 1))
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# reshape back
y_pred_inv = y_pred_inv.reshape(y_pred.shape)
y_test_inv = y_test_inv.reshape(y_test.shape)

# %%
import matplotlib.pyplot as plt

day = 40


plt.figure(figsize=(14,5))
plt.grid()
plt.plot(y_test_inv[day]/3, label="Actual Values")
plt.plot(y_pred_inv[day]/3, label="Forecasted Values")
plt.xlabel("Time Steps (15-min)")
plt.ylabel("Normalized Load (kW)")
plt.legend()
plt.title(" LSTM Load Forecast - Next 24 Hours")
plt.show()

# %%
import matplotlib.pyplot as plt

day = 40


plt.figure(figsize=(14,5))
plt.grid()
plt.plot(y_test_inv[day]/3, label="Actual Values")
plt.plot(y_pred_inv[day]/3, label="Forecasted Values")
plt.xlabel("Time Steps (15-min)")
plt.ylabel("Normalized Load (kW)")
plt.legend()
# plt.title("Load Forecast - Next 24 Hours")

plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'legend.fontsize': 12,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12
})
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, r2_score

y_test_flat = y_test_inv.reshape(-1)
y_pred_flat = y_pred_inv.reshape(-1)

mae = mean_absolute_error(y_test_flat, y_pred_flat)
rmse = np.sqrt(np.mean((y_test_flat - y_pred_flat)**2))
r2 = r2_score(y_test_flat, y_pred_flat)

print("MAE:", mae)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 0.6783092231418255
# RMSE: 1.0385295542230746
# R2: 0.24530193536953948
